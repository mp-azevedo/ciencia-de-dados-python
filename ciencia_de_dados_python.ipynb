# %% [markdown]
# <a href="https://colab.research.google.com/github/mp-azevedo/ciencia-de-dados-python/blob/main/ciencia_de_dados_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aplicação Prática de Python na Ciência de Dados
#
# ## Descrição
#
# A atividade foi realizada utilizando o Google Colab para executar os códigos em Python.
#
# Inicialmente, foi utilizado o comando `pip list` para visualizar os pacotes disponíveis no ambiente. Em seguida, foram testadas algumas estruturas básicas da linguagem, como o uso do loop `for`, criação de dicionário (`dict`) e conversão de dicionário para lista (`list`).
#
# Na segunda etapa, foi utilizada a biblioteca pandas para carregar um arquivo em formato Excel. A partir disso, foram analisados os dados, verificando a quantidade de linhas e colunas, os tipos de variáveis, a aparência dos dados e a existência de valores faltantes.
#
# ## Análise
#
# Os dados foram carregados corretamente em um DataFrame, permitindo identificar suas características principais. Foi possível observar tanto variáveis numéricas quanto categóricas, além de verificar a estrutura geral do conjunto de dados.
#
# ## Conclusão
#
# A atividade permitiu entender o funcionamento básico do Python e aplicar comandos simples para análise de dados utilizando o pandas.

# %% [markdown]
# ---

# %%
# Visualizar pacotes disponíveis (Limitei para mostrar apenas 20, para não ficar tão longo)
# !pip list | head -n 20
# Out:
# Package                                  Version
# ---------------------------------------- -------------------
# absl-py                                  1.4.0
# accelerate                               1.13.0
# access                                   1.1.10.post3
# affine                                   2.4.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.4
# aiosignal                                1.4.0
# aiosqlite                                0.22.1
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.18.4
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# ...

# %% [markdown]
# ---

# %%
# Loop for
for counter in range(5):
    print(counter)

# Dicionário
example_dict = {'apples':5, 'oranges':8, 'bananas':13}

# Converter para lista
dict_to_list = list(example_dict)
dict_to_list
# Out:
# 0
# 1
# 2
# 3
# 4
# ['apples', 'oranges', 'bananas']

# %% [markdown]
# ---

# %%
import pandas as pd
df = pd.read_excel('default_of_credit_card_clients__courseware_version_1_21_19.xls')

# Quantidade de colunas
print("Quantidade de colunas:", df.shape[1])

# Quantidade de linhas
print("Quantidade de linhas:", df.shape[0])
# Out:
# Quantidade de colunas: 25
# Quantidade de linhas: 30000

# %% [markdown]
# ---

# %%
import pandas as pd
df = pd.read_excel('default_of_credit_card_clients__courseware_version_1_21_19.xls')

# Tipos de dados
print("Tipos de dados:")
print(df.dtypes)

# Separação
categoricas = df.select_dtypes(include=['object']).columns
numericas = df.select_dtypes(exclude=['object']).columns

print("\nVariáveis categóricas:")
print(list(categoricas))

print("\nVariáveis numéricas:")
print(list(numericas))
# Out:
# Tipos de dados:
# ID                            object
# LIMIT_BAL                      int64
# SEX                            int64
# EDUCATION                      int64
# MARRIAGE                       int64
# AGE                            int64
# PAY_1                         object
# PAY_2                          int64
# PAY_3                          int64
# PAY_4                          int64
# PAY_5                          int64
# PAY_6                          int64
# BILL_AMT1                      int64
# BILL_AMT2                      int64
# BILL_AMT3                      int64
# BILL_AMT4                      int64
# BILL_AMT5                      int64
# BILL_AMT6                      int64
# PAY_AMT1                       int64
# PAY_AMT2                       int64
# PAY_AMT3                       int64
# PAY_AMT4                       int64
# PAY_AMT5                       int64
# PAY_AMT6                       int64
# default payment next month     int64
# ...

# %% [markdown]
# ---

# %%
import pandas as pd
df = pd.read_excel('default_of_credit_card_clients__courseware_version_1_21_19.xls')

# Primeiras linhas
print("Primeiras linhas:")
print(df.head())

# Estatísticas
print("\nResumo estatístico:")
print(df.describe())

# Frequência categórica (exemplo)
print("\nFrequência da variável SEX:")
print(df['SEX'].value_counts())
# Out:
# Primeiras linhas:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
# ...

# %% [markdown]
# ---

# %%
import pandas as pd
df = pd.read_excel('default_of_credit_card_clients__courseware_version_1_21_19.xls')

print("Dados faltantes:")
print(df.isnull().sum())
# Out:
# Dados faltantes:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64
